# %% [markdown]
# <a href="https://colab.research.google.com/github/623020514-5/data_viz_2022/blob/main/Final_DataViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# จากโจทย์
# ให้นักศึกษาสร้าง Dashboard แสดงรายงานเกี่ยวกับข้อมูลการตรวจโรค(ov) จาก ไฟล์ alldb.csv และ hospital_list.xlsx
# ( ดาวน์โหลดจาก https://drive.google.com/drive/folders/1D_Z0fjTki6U6ECbgh2V3wBOSdOXS81YT?fbclid=IwAR2TOFCt16PG2k9xeKIA7jnTEm63uTzd3nRacpzhJEp3d3-6QCtWz3tQskw )

# %% [markdown]
# #**เรียกใช้ฟังฟ์ชั่น**

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os           #เพื่อจัดการกับไฟล์ และ ตัว path ที่เราจะนำเข้า
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# #**นำเข้าไฟล์**

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive') # เช็คว่าเชื่อมติดหรือไม่
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/FinalDataViz'

# %% [markdown]
# ##**ตารางที่ 1**

# %%
data1 = pd.read_csv(os.path.join(path,'alldb.csv'))
data1
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# 0      NaN         NaN  NaN               NaN    NaN       NaN
# 1      NaN  2022-02-24  NaN        iPhone10,4  05310  10:50:32
# 2      NaN         NaN  NaN               NaN    NaN       NaN
# 3      NaN  2022-02-23    0        iPhone13,4  05087  09:59:47
# 4      NaN  2022-02-23  NaN        iPhone13,4  05087  09:44:06
# ...    ...         ...  ...               ...    ...       ...
# 40030  NaN         NaN  NaN        iPhone13,4  01234       NaN
# 40031  NaN         NaN    2        iPhone10,5  01234       NaN
# 40032  NaN         NaN    1        iPhone13,4  01234       NaN
# 40033  NaN         NaN  NaN  Samsung SM-A115F  01234       NaN
# 40034  NaN         NaN    1  Samsung SM-A115F  01234       NaN
#
#                  urine  pid            PartitionKey                  title  \
# 0                  NaN  NaN                     NaN  data is not completed
# 1                  NaN  NaN                     NaN  data is not completed
# 2                  NaN  NaN                     NaN  data is not completed
# 3      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# 4      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# ...                ...  ...                     ...                    ...
# 40030              NaN    5     เกษศิรินทร์  ไชยลาภ  data is not completed
# 40031  ปกติ (เหลืองใส)    5  เถลิงเกียรติ เสริฐเลิศ  data is not completed
# 40032  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
# 40033              NaN    1                    เสรี  data is not completed
# 40034  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
#
#                          age
# 0      data is not completed
# 1      data is not completed
# 2      data is not completed
# 3      data is not completed
# 4      data is not completed
# ...                      ...
# 40030  data is not completed
# 40031  data is not completed
# 40032  data is not completed
# 40033  data is not completed
# 40034  data is not completed
#
# [40035 rows x 14 columns]

# %% [markdown]
# ##**ตวจสอบขนาด**

# %%
data1.shape
# Out:
# (40035, 14)

# %% [markdown]
# เนื่องจากข้อมูลมีจำนวนมาก แต่เราไม่ได้ใช้ทั้งหมด เพื่อง่ายต่อการทำ prepocessing ดังนั้นจะตัดมาแค่ข้อมูลที่ต้องการใช้จริงๆ ตามโจทย์

# %% [markdown]
# ### ตรวจสอบหาค่า NaN หรือ Missing

# %%
data1.isnull().any()  # ตรวจสอบหาค่า missing
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# Unnamed: 0      False
# user             True
# RowKey           True
# care             True
# date             True
# ov               True
# phone            True
# site             True
# time             True
# urine            True
# pid              True
# PartitionKey     True
# title            True
# age              True
# dtype: bool

# %% [markdown]
# จากผลเราจะพิจารณาจากการอ่านค่า True และ False ถ้า True คือ มีค่า missing ดังนั้น จะเห็นได้ว่าข้อมูลมีค่า missing เกือบในทุกคอลัมน์ ดังนั้น สามารถอนุมานได้เลยว่า ข้อมูลมีค่า missing จำนวนมาก จึงไม่เหมาะกับตัดข้อมูล หรือ .dropna
# จึงพิจารณาให้ใช้วิธีแทนค่าเฉพาะคอลัมน์ข้อมูลที่เราต้องการใช้

# %% [markdown]
# # Data Preprocessing

# %%
data = data1[['user','RowKey','date','ov','phone','site','time','urine','PartitionKey','title','age']]
data
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#         ov             phone   site      time            urine  \
# 0      NaN               NaN    NaN       NaN              NaN
# 1      NaN        iPhone10,4  05310  10:50:32              NaN
# 2      NaN               NaN    NaN       NaN              NaN
# 3        0        iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)
# 4      NaN        iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)
# ...    ...               ...    ...       ...              ...
# 40030  NaN        iPhone13,4  01234       NaN              NaN
# 40031    2        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)
# 40032    1        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)
# 40033  NaN  Samsung SM-A115F  01234       NaN              NaN
# 40034    1  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)
#
#                  PartitionKey                  title                    age
# 0                         NaN  data is not completed  data is not completed
# 1                         NaN  data is not completed  data is not completed
# 2                         NaN  data is not completed  data is not completed
# 3                         NaN  data is not completed  data is not completed
# 4                         NaN  data is not completed  data is not completed
# ...                       ...                    ...                    ...
# 40030     เกษศิรินทร์  ไชยลาภ  data is not completed  data is not completed
# 40031  เถลิงเกียรติ เสริฐเลิศ  data is not completed  data is not completed
# 40032                    เสรี  data is not completed  data is not completed
# 40033                    เสรี  data is not completed  data is not completed
# 40034                    เสรี  data is not completed  data is not completed
#
# [40035 rows x 11 columns]

# %%
data_drop = data.dropna()
data_drop
# Out:
#          user                                RowKey        date ov  \
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23  0
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23  0
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25  0
# 191     12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30  4
# 192     91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30  4
# ...       ...                                   ...         ... ..
# 40013   ttest                        crqcufokmn.png  2022-02-21  2
# 40014   ttest                        gzxgflnowr.png  2022-02-21  2
# 40016     xxx                        jytlopevha.png  2022-02-17  3
# 40022     yyy                        ivccsksowb.png  2022-02-17  2
# 40023     zzz                        psudrnccsh.png  2022-02-17  2
#
#                   phone   site      time            urine PartitionKey  \
# 186          iPhone11,8  04312  09:45:28  ปกติ (เหลืองใส)       0-1528
# 187          iPhone11,8  04312  10:06:45  ปกติ (เหลืองใส)       0-1544
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)        00001
# ...                 ...    ...       ...              ...          ...
# 40013  Samsung SM-G998B   test  14:23:45             ขุ่น         x001
# 40014  Samsung SM-G998B   test  14:23:43             ขุ่น         x001
# 40016  Samsung SM-N950F    xxx  00:01:06  ปกติ (เหลืองใส)          xxx
# 40022  Samsung SM-N950F    yyy  08:41:05   มีเม็ดเลือดแดง          yyy
# 40023  Samsung SM-N950F    zzz  08:41:04          มีตะกอน          zzz
#
#                        title                    age
# 186    data is not completed  data is not completed
# 187    data is not completed  data is not completed
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# ...                      ...                    ...
# 40013  data is not completed  data is not completed
# 40014  data is not completed  data is not completed
# 40016  data is not completed  data is not completed
# 40022  data is not completed  data is not completed
# 40023  data is not completed  data is not completed
#
# [38135 rows x 11 columns]

# %%
data_drop = data_drop[(data_drop['PartitionKey'].astype(str).str.isdigit()) & (data_drop['PartitionKey'].str.len() == 5)]      # เลือกมาเฉพาะ คอลัมน์ PartitionKey ที่เป็นตัวเลข & มีตัวเลข เท่ากับ 5 ตัว
print(data_drop.shape)                                                                            
data_drop.head()
# Out:
# (37772, 11)
#       user                                RowKey        date ov       phone  \
# 191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30  4  iPhone12,3
# 192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30  4  iPhone14,3
# 193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30  3  iPhone13,4
# 194  13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29  3   iPhone9,4
# 195  28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31  0  iPhone13,3
#
#       site      time            urine PartitionKey   title age
# 191  06307  14:46:08  ปกติ (เหลืองใส)        00001  นางสาว  47
# 192  05328  15:27:45  ปกติ (เหลืองใส)        00001     นาง  41
# 193  06302  10:16:46  ปกติ (เหลืองใส)        00001     นาง  55
# 194  05059  12:26:38  ปกติ (เหลืองใส)        00001     นาย  66
# 195  06334  14:57:41  ปกติ (เหลืองใส)        00001  นางสาว  50

# %%
set(data_drop['PartitionKey'])
# Out:
# {'04095',
#  '00722',
#  '00779',
#  '00703',
#  '03292',
#  '01149',
#  '02720',
#  '00151',
#  '08942',
#  '01473',
#  '02778',
#  '04696',
#  '00930',
#  '01737',
#  '01797',
#  '09011',
#  '02008',
#  '01082',
#  '00387',
#  '02026',
#  '03983',
#  '01708',
#  '05247',
#  '00419',
#  '06182',
#  '02405',
#  '09007',
#  '00783',
#  '00688',
#  '00287',
#  '01744',
#  '01854',
#  '02244',
#  '02500',
#  '05327',
#  '00144',
#  '00684',
#  '01018',
#  '02749',
#  '02917',
#  '01122',
#  '01331',
#  '04627',
#  '00512',
#  '08918',
#  '00863',
#  '00719',
#  '01866',
#  '02792',
#  '00855',
#  '03098',
#  '00093',
#  '01362',
#  '00496',
#  '04626',
#  '03096',
#  '01683',
#  '01167',
#  '02484',
#  '01031',
#  '01939',
#  '00698',
#  '00073',
#  '00455',
#  '00792',
#  '00940',
#  '00165',
#  '01090',
#  '01071',
#  '01338',
#  '02946',
#  '08930',
#  '02627',
#  '08995',
#  '02028',
#  '03503',
#  '08971',
#  '00643',
#  '00207',
#  '01654',
#  '01611',
#  '01892',
#  '02075',
#  '03073',
#  '00625',
#  '03939',
#  '01868',
#  '03124',
#  '03487',
#  '01131',
#  '01600',
#  '00818',
#  '02327',
#  '02702',
#  '04186',
#  '00461',
#  '05189',
#  '01632',
#  '02095',
#  '02144',
#  '10998',
#  '01692',
#  '01133',
#  '01666',
#  '01177',
#  '01723',
#  '00192',
#  '02738',
#  '03358',
#  '00994',
#  '02666',
#  '00246',
#  '02062',
#  '01065',
#  '04052',
#  '00696',
#  '02295',
#  '03100',
#  '02808',
#  '03310',
#  '01138',
#  '02992',
#  '02457',
#  '00442',
#  '03007',
#  '01943',
#  ...}

# %%
data_drop = data_drop[(data_drop['site'].astype(str).str.isdigit()) & (data_drop['site'].str.len() == 5)]      # เลือกมาเฉพาะ คอลัมน์ site ที่เป็นตัวเลข & มีตัวเลข เท่ากับ 5 ตัว
print(data_drop.shape)                                                                            
data_drop.head()
# Out:
# (37764, 11)
#       user                                RowKey        date ov       phone  \
# 191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30  4  iPhone12,3
# 192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30  4  iPhone14,3
# 193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30  3  iPhone13,4
# 194  13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29  3   iPhone9,4
# 195  28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31  0  iPhone13,3
#
#       site      time            urine PartitionKey   title age
# 191  06307  14:46:08  ปกติ (เหลืองใส)        00001  นางสาว  47
# 192  05328  15:27:45  ปกติ (เหลืองใส)        00001     นาง  41
# 193  06302  10:16:46  ปกติ (เหลืองใส)        00001     นาง  55
# 194  05059  12:26:38  ปกติ (เหลืองใส)        00001     นาย  66
# 195  06334  14:57:41  ปกติ (เหลืองใส)        00001  นางสาว  50

# %%
set(data_drop['site'])
# Out:
# {'00027',
#  '00040',
#  '00513',
#  '00579',
#  '00580',
#  '02759',
#  '03432',
#  '03626',
#  '04275',
#  '04279',
#  '04280',
#  '04281',
#  '04302',
#  '04312',
#  '04313',
#  '04321',
#  '04322',
#  '04326',
#  '04337',
#  '04347',
#  '04349',
#  '04351',
#  '04352',
#  '04355',
#  '04374',
#  '04376',
#  '04380',
#  '04384',
#  '04387',
#  '04388',
#  '04390',
#  '04391',
#  '04396',
#  '04399',
#  '04401',
#  '04402',
#  '04403',
#  '04404',
#  '04405',
#  '04406',
#  '04407',
#  '04408',
#  '04433',
#  '04434',
#  '04435',
#  '04436',
#  '04437',
#  '04438',
#  '04441',
#  '04443',
#  '04455',
#  '04456',
#  '04457',
#  '04458',
#  '04475',
#  '04478',
#  '04558',
#  '04936',
#  '04968',
#  '04970',
#  '04971',
#  '04973',
#  '04974',
#  '04977',
#  '04980',
#  '04981',
#  '04982',
#  '04983',
#  '04984',
#  '04985',
#  '04986',
#  '04989',
#  '04990',
#  '04992',
#  '04993',
#  '04994',
#  '04995',
#  '04996',
#  '04997',
#  '04999',
#  '05000',
#  '05001',
#  '05002',
#  '05003',
#  '05004',
#  '05005',
#  '05006',
#  '05007',
#  '05008',
#  '05009',
#  '05010',
#  '05011',
#  '05012',
#  '05013',
#  '05015',
#  '05016',
#  '05019',
#  '05021',
#  '05022',
#  '05023',
#  '05024',
#  '05025',
#  '05026',
#  '05027',
#  '05028',
#  '05029',
#  '05032',
#  '05033',
#  '05034',
#  '05035',
#  '05038',
#  '05040',
#  '05042',
#  '05044',
#  '05045',
#  '05047',
#  '05048',
#  '05049',
#  '05052',
#  '05054',
#  '05055',
#  '05058',
#  '05059',
#  '05060',
#  '05061',
#  '05062',
#  '05063',
#  '05064',
#  '05065',
#  '05066',
#  '05067',
#  '05068',
#  '05069',
#  '05072',
#  '05074',
#  '05075',
#  '05077',
#  '05079',
#  '05080',
#  '05081',
#  '05082',
#  '05083',
#  '05084',
#  '05086',
#  '05087',
#  '05088',
#  '05090',
#  '05091',
#  '05094',
#  '05097',
#  '05098',
#  '05100',
#  '05101',
#  '05102',
#  '05103',
#  '05107',
#  '05111',
#  '05112',
#  '05113',
#  '05115',
#  '05116',
#  '05117',
#  '05119',
#  '05120',
#  '05123',
#  '05125',
#  '05126',
#  '05128',
#  '05129',
#  '05131',
#  '05132',
#  '05133',
#  '05135',
#  '05136',
#  '05141',
#  '05143',
#  '05144',
#  '05146',
#  '05147',
#  '05152',
#  '05154',
#  '05157',
#  '05158',
#  '05162',
#  '05166',
#  '05172',
#  '05173',
#  '05175',
#  '05177',
#  '05178',
#  '05180',
#  '05181',
#  '05182',
#  '05185',
#  '05187',
#  '05188',
#  '05192',
#  '05193',
#  '05194',
#  '05195',
#  '05196',
#  '05198',
#  '05200',
#  '05203',
#  '05205',
#  '05207',
#  '05210',
#  '05211',
#  '05213',
#  '05214',
#  '05215',
#  '05219',
#  '05220',
#  '05222',
#  '05223',
#  '05224',
#  '05225',
#  '05226',
#  '05228',
#  '05229',
#  '05233',
#  '05236',
#  '05237',
#  '05238',
#  '05240',
#  '05242',
#  '05244',
#  '05245',
#  '05246',
#  '05247',
#  '05248',
#  '05249',
#  '05250',
#  '05251',
#  '05252',
#  '05253',
#  '05254',
#  '05255',
#  '05256',
#  '05257',
#  '05258',
#  '05259',
#  '05260',
#  '05261',
#  '05264',
#  '05265',
#  '05291',
#  '05298',
#  '05300',
#  '05304',
#  '05310',
#  '05311',
#  '05312',
#  '05313',
#  '05314',
#  '05315',
#  '05316',
#  '05322',
#  '05323',
#  '05324',
#  '05325',
#  '05327',
#  '05328',
#  '05332',
#  '05335',
#  '05337',
#  '05338',
#  '05339',
#  '05340',
#  '05343',
#  '05344',
#  '05345',
#  '05346',
#  '05349',
#  '05350',
#  '05351',
#  '05352',
#  '05354',
#  '05355',
#  '05356',
#  '05357',
#  '05358',
#  '05359',
#  '05360',
#  '05361',
#  '05363',
#  '05365',
#  '05366',
#  '05367',
#  '05368',
#  '05370',
#  '05371',
#  '05373',
#  '05378',
#  '05386',
#  '05391',
#  '05392',
#  '05393',
#  '05394',
#  '05395',
#  '05396',
#  '05413',
#  '05414',
#  '05415',
#  '05416',
#  '05418',
#  '05419',
#  '05422',
#  '05423',
#  '05424',
#  '05425',
#  '05428',
#  '05431',
#  '05432',
#  '05433',
#  '05434',
#  '05435',
#  '05436',
#  '05437',
#  '05439',
#  '05440',
#  '05441',
#  '05442',
#  '05541',
#  '06238',
#  '06251',
#  '06253',
#  '06254',
#  '06255',
#  '06256',
#  '06257',
#  '06259',
#  '06260',
#  '06261',
#  '06263',
#  '06265',
#  '06267',
#  '06268',
#  '06270',
#  '06271',
#  '06272',
#  '06273',
#  '06274',
#  '06275',
#  '06276',
#  '06277',
#  '06278',
#  '06279',
#  '06280',
#  '06281',
#  '06282',
#  '06283',
#  '06285',
#  '06286',
#  '06287',
#  '06288',
#  '06289',
#  '06290',
#  '06291',
#  '06292',
#  '06293',
#  '06294',
#  '06295',
#  '06296',
#  '06297',
#  '06298',
#  '06299',
#  '06300',
#  '06301',
#  '06302',
#  '06307',
#  '06308',
#  '06309',
#  '06310',
#  '06311',
#  '06312',
#  '06314',
#  '06315',
#  '06316',
#  '06318',
#  '06319',
#  '06320',
#  '06321',
#  '06322',
#  '06323',
#  '06324',
#  '06325',
#  '06326',
#  '06327',
#  '06328',
#  '06329',
#  '06330',
#  '06331',
#  '06332',
#  '06333',
#  '06334',
#  '10360',
#  '10673',
#  '11010',
#  '11055',
#  '11056',
#  '11057',
#  '11059',
#  '11060',
#  '11066',
#  '11069',
#  '11070',
#  '11072',
#  '11073',
#  '11084',
#  '11088',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11163',
#  '11164',
#  '11165',
#  '11748',
#  '11749',
#  '13777',
#  '13937',
#  '13941',
#  '13943',
#  '13944',
#  '13946',
#  '13947',
#  '13948',
#  '13949',
#  '13952',
#  '13953',
#  '13954',
#  '13955',
#  '13962',
#  '13963',
#  '13966',
#  '13984',
#  '14005',
#  '14007',
#  '14280',
#  '14284',
#  '14843',
#  '24650',
#  '27988',
#  '27990',
#  '28017',
#  '99795'}

# %% [markdown]
# ## เปลี่ยน type ข้อมูลเป็น String

# %%
import numpy as np

# %% [markdown]
# ### เปลี่ยน user, site, ov, PartitionKey, age เป็นตัวเลขเท่านั้น (int)

# %% [markdown]
# โดยการตั้งค่า  error='coerce' จะแปลงค่าที่ไม่ใช่ตัวเลขเป็น  NaN

# %%
data_drop['user'] = pd.to_numeric(data_drop['user'], errors='coerce')
data_drop['ov'] = pd.to_numeric(data_drop['ov'], errors='coerce')
data_drop['age'] = pd.to_numeric(data_drop['age'], errors='coerce');
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data_drop.dtypes
# Out:
# user            float64
# RowKey           object
# date             object
# ov              float64
# phone            object
# site             object
# time             object
# urine            object
# PartitionKey     object
# title            object
# age               int64
# dtype: object

# %% [markdown]
# ตอนนี้จะสังเกตเห็น ค่า NaNโดยที่ประเภทข้อมูลเป็น float
#
# สามารถทำโดยแทนที่ค่า 'NaN' ด้วยค่า '0' โดยใช้ df.replace:

# %%
data_drop = data_drop.replace(np.nan, 0, regex=True)
data_drop['user'] = data_drop['user'].astype(int)
data_drop['ov'] = data_drop['ov'].astype(int)
data_drop['age'] = data_drop['age'].astype(int)

# %%
data_drop.dtypes
# Out:
# user             int64
# RowKey          object
# date            object
# ov               int64
# phone           object
# site            object
# time            object
# urine           object
# PartitionKey    object
# title           object
# age              int64
# dtype: object

# %% [markdown]
# >เปลี่ยน Rowkey phone เเละ urine เป็น String

# %% [markdown]
# ### เปลี่ยน RowKey, phone, urine, title เป็น String

# %%
data_drop.astype({'RowKey':'string', 'phone':'string','urine':'string','title':'string'}).dtypes
# Out:
# user             int64
# RowKey          string
# date            object
# ov               int64
# phone           string
# site            object
# time            object
# urine           string
# PartitionKey    object
# title           string
# age              int64
# dtype: object

# %%
data_drop
# Out:
#         user                                RowKey        date  ov  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30   4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30   3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31   0
# ...      ...                                   ...         ...  ..
# 39417  26462                        cywpeqziic.png  2022-03-21   2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22   2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21   0
# 39420  26462                        vdxxgljykj.png  2022-03-21   1
# 39478      0                        wwpnkeptlc.png  2022-02-26   0
#
#                   phone   site      time                             urine  \
# 191          iPhone12,3  06307  14:46:08                   ปกติ (เหลืองใส)
# 192          iPhone14,3  05328  15:27:45                   ปกติ (เหลืองใส)
# 193          iPhone13,4  06302  10:16:46                   ปกติ (เหลืองใส)
# 194           iPhone9,4  05059  12:26:38                   ปกติ (เหลืองใส)
# 195          iPhone13,3  06334  14:57:41                   ปกติ (เหลืองใส)
# ...                 ...    ...       ...                               ...
# 39417         Vivo 1920  11069  13:59:04                   ปกติ (เหลืองใส)
# 39418        iPhone13,4  11069  13:41:47                   ปกติ (เหลืองใส)
# 39419        iPhone13,4  11069  14:17:46                   ปกติ (เหลืองใส)
# 39420        Vivo V2050  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
# 39478  Samsung SM-G998B  13777  01:26:34                           สีน้ำนม
#
#       PartitionKey   title  age
# 191          00001  นางสาว   47
# 192          00001     นาง   41
# 193          00001     นาง   55
# 194          00001     นาย   66
# 195          00001  นางสาว   50
# ...            ...     ...  ...
# 39417        11005     นาย   28
# 39418        11006     นาง   72
# 39419        11007     นาง   48
# 39420        11008     นาย   36
# 39478        12285  นางสาว   22
#
# [37764 rows x 11 columns]

# %% [markdown]
# > กำหนด ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)

# %%
set(data_drop['ov'])
# Out:
# {0, 1, 2, 3, 4}

# %% [markdown]
# จะเห็นว่า ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ) อยู่แล้ว ดังนั้นไม่ต้องแก้ไขอะไร

# %% [markdown]
# >กำหนดรูปแบบของ time เป็น hh-mm-ss

# %%
data_drop['time'] = data_drop['time'].replace(':','-',regex=True)

# %%
data_drop
# Out:
#         user                                RowKey        date  ov  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30   4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30   3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31   0
# ...      ...                                   ...         ...  ..
# 39417  26462                        cywpeqziic.png  2022-03-21   2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22   2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21   0
# 39420  26462                        vdxxgljykj.png  2022-03-21   1
# 39478      0                        wwpnkeptlc.png  2022-02-26   0
#
#                   phone   site      time                             urine  \
# 191          iPhone12,3  06307  14-46-08                   ปกติ (เหลืองใส)
# 192          iPhone14,3  05328  15-27-45                   ปกติ (เหลืองใส)
# 193          iPhone13,4  06302  10-16-46                   ปกติ (เหลืองใส)
# 194           iPhone9,4  05059  12-26-38                   ปกติ (เหลืองใส)
# 195          iPhone13,3  06334  14-57-41                   ปกติ (เหลืองใส)
# ...                 ...    ...       ...                               ...
# 39417         Vivo 1920  11069  13-59-04                   ปกติ (เหลืองใส)
# 39418        iPhone13,4  11069  13-41-47                   ปกติ (เหลืองใส)
# 39419        iPhone13,4  11069  14-17-46                   ปกติ (เหลืองใส)
# 39420        Vivo V2050  11069  10-54-49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
# 39478  Samsung SM-G998B  13777  01-26-34                           สีน้ำนม
#
#       PartitionKey   title  age
# 191          00001  นางสาว   47
# 192          00001     นาง   41
# 193          00001     นาง   55
# 194          00001     นาย   66
# 195          00001  นางสาว   50
# ...            ...     ...  ...
# 39417        11005     นาย   28
# 39418        11006     นาง   72
# 39419        11007     นาง   48
# 39420        11008     นาย   36
# 39478        12285  นางสาว   22
#
# [37764 rows x 11 columns]

# %%
TF=list()
for each_row in data_drop.iterrows():
    if (10000 < each_row[1]['user'] < 60000):  #each_row คือ ตัวเลข
        TF.append(True)
    else:
        TF.append(False)

data2= data_drop[TF]

# %%
data2
# Out:
#         user                                RowKey        date  ov  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31   0
# 196    41340  1C640780-7513-43C0-B1E4-4A535DA468F3  2022-03-30   3
# 198    22119  1FBE544D-7313-43EA-95EF-91DAD0513808  2022-04-01   4
# ...      ...                                   ...         ...  ..
# 39416  26462                        ieotqfnqcq.png  2022-03-22   1
# 39417  26462                        cywpeqziic.png  2022-03-21   2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22   2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21   0
# 39420  26462                        vdxxgljykj.png  2022-03-21   1
#
#             phone   site      time                             urine  \
# 191    iPhone12,3  06307  14-46-08                   ปกติ (เหลืองใส)
# 194     iPhone9,4  05059  12-26-38                   ปกติ (เหลืองใส)
# 195    iPhone13,3  06334  14-57-41                   ปกติ (เหลืองใส)
# 196    iPhone14,5  06288  10-28-02                   ปกติ (เหลืองใส)
# 198     iPhone8,1  06261  15-40-17                   ปกติ (เหลืองใส)
# ...           ...    ...       ...                               ...
# 39416   Vivo 1920  11069  14-03-12                   ปกติ (เหลืองใส)
# 39417   Vivo 1920  11069  13-59-04                   ปกติ (เหลืองใส)
# 39418  iPhone13,4  11069  13-41-47                   ปกติ (เหลืองใส)
# 39419  iPhone13,4  11069  14-17-46                   ปกติ (เหลืองใส)
# 39420  Vivo V2050  11069  10-54-49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
#
#       PartitionKey   title  age
# 191          00001  นางสาว   47
# 194          00001     นาย   66
# 195          00001  นางสาว   50
# 196          00001  นางสาว   57
# 198          00001     นาง   50
# ...            ...     ...  ...
# 39416        11003  นางสาว   33
# 39417        11005     นาย   28
# 39418        11006     นาง   72
# 39419        11007     นาง   48
# 39420        11008     นาย   36
#
# [17967 rows x 11 columns]

# %% [markdown]
# > เปลี่ยนคอลัมน์ title เป็นเพศ

# %%
set(data2['title'])   # ดู set ของข้อมูล
# Out:
# {'  นาง',
#  ' นาง',
#  'Mrs',
#  'ด.ช.',
#  'ด.ญ.',
#  'ด.ต.',
#  'น.ส',
#  'น.ส ',
#  'น.ส.',
#  'นส',
#  'นส.',
#  'นส. ',
#  'นาง',
#  'นาง ',
#  'นางl',
#  'นางสาว',
#  'นางสาว ',
#  'นาบ',
#  'นาย',
#  'นาย ',
#  'นาย  ',
#  'นาว',
#  'นาวสาว',
#  'นา่ง',
#  'พจอ.',
#  'พระ',
#  'พระครุ',
#  'พลฯ',
#  'ร.ต.',
#  'ร.ต.ต.',
#  'ว่าที่ร้อยตรี',
#  'ืนาง',
#  'เด็กชาย',
#  'เด็กหญิง'}

# %%
data2['title'].replace({'  นาง':'หญิง',
                    ' นาง':'หญิง',
                    ' นางสาว':'หญิง',
                    ' นาย':'ชาย',
                    'Mrs':'หญิง',
                    'ชาย':'ชาย',
                    'ด.ช.':'ชาย',
                    'ด.ญ.':'หญิง',
                    'ด.ต.':'ไม่ระบุ',
                    'น':'ไม่ระบุ',
                    'น.ส':'หญิง',
                    'น.ส ':'หญิง',
                    'น.ส.':'หญิง',
                    'นส':'หญิง',
                    'นส.':'หญิง',
                    'นส. ':'หญิง',
                    'นาง':'หญิง',
                    'นาง ':'หญิง',
                    'นาง.':'หญิง',
                    'นางl':'หญิง',
                    'นางสาว':'หญิง',
                    'นางสาว ':'หญิง',
                    'นางสาว                   ':'หญิง',
                    'นาน':'ชาย',
                    'นาบ':'ชาย',
                    'นาย':'ชาย',
                    'นาย ':'ชาย',
                    'นาย  ':'ชาย',
                    'นาว':'หญิง',
                    'นาวสาว':'หญิง',
                    'นา่ง':'หญิง',
                    'น่าย':'ชาย',
                    'พจอ.':'ไม่ระบุ',
                    'พระ':'ชาย',
                    'พระครุ':'ไม่ระบุ',
                    'พระปลัด':'ไม่ระบุ',
                    'พลฯ':'ไม่ระบุ',
                    'ร.ต.':'ไม่ระบุ',
                    'ร.ต.ต.':'ไม่ระบุ',
                    'ร.ต.ท.':'ไม่ระบุ',
                    'ร.ต.อ.':'ไม่ระบุ',
                    'รต.':'ไม่ระบุ',
                    'ว่าที่ ร.ต.':'ไม่ระบุ',
                    'ว่าที่ ร.ท.':'ไม่ระบุ',
                    'ว่าที่ร้อยตรี':'ไม่ระบุ',
                    0:'ไม่ระบุ',
                    'data is not completed':'ไม่ระบุ',
                    'okp':'ไม่ระบุ',
                    'ส.อ.':'ไม่ระบุ',
                    'ืนาง':'หญิง',
                    'เด็กชาย':'ชาย',
                    'เด็กหญิง':'หญิง'},inplace=True)

# %%
set(data2['title'])
# Out:
# {'ชาย', 'หญิง', 'ไม่ระบุ'}

# %%
data_re = data2.rename(columns={'title':'sex'}) 
data_re.head(5)
# Out:
#       user                                RowKey        date  ov       phone  \
# 191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4  iPhone12,3
# 194  13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3   iPhone9,4
# 195  28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31   0  iPhone13,3
# 196  41340  1C640780-7513-43C0-B1E4-4A535DA468F3  2022-03-30   3  iPhone14,5
# 198  22119  1FBE544D-7313-43EA-95EF-91DAD0513808  2022-04-01   4   iPhone8,1
#
#      site      time            urine  PartitionKey   sex  age
# 191  6307  14-46-08  ปกติ (เหลืองใส)             1  หญิง   47
# 194  5059  12-26-38  ปกติ (เหลืองใส)             1   ชาย   66
# 195  6334  14-57-41  ปกติ (เหลืองใส)             1  หญิง   50
# 196  6288  10-28-02  ปกติ (เหลืองใส)             1  หญิง   57
# 198  6261  15-40-17  ปกติ (เหลืองใส)             1  หญิง   50

# %%
data_re.shape
# Out:
# (17967, 11)

# %%
data_01 = data_re

# %%
data_01
# Out:
#         user                                RowKey        date  ov  \
# 39370  26462  6C55B69E-8E4C-46B0-B0D7-4754A529EE3C  2022-03-21   4
# 39371  26462                        eehzjpxnjw.png  2022-03-22   1
# 39372  26462                        cjukggkdgy.png  2022-03-22   0
# 39373  26462                        wpnaiylzxi.png  2022-03-22   0
# 39374  26462                        pnqumypemv.png  2022-03-22   3
# 39375  26462                        rkkutomafv.png  2022-03-22   0
# 39376  26462                        emcshsfjwi.png  2022-03-22   0
# 39377  26462                        wgxurysjec.png  2022-03-22   2
# 39378  26462                        vanquopswi.png  2022-03-22   2
# 39379  26462                        bfceftfurl.png  2022-03-22   1
# 39380  26462                        lybdixwhaq.png  2022-03-22   0
# 39381  26462                        alevoqyzru.png  2022-03-22   0
# 39382  26462                        gukjamcmkc.png  2022-03-22   0
# 39383  26462                        vdnnojfhka.png  2022-03-22   0
# 39384  26462                        byyhydmqlz.png  2022-03-21   0
# 39385  26462  5CB6F5EB-324D-448C-84AD-C9D48B23684E  2022-03-22   4
# 39386  26462                        sxzmzrsmyf.png  2022-03-21   1
# 39387  26462                        vmenrqvavo.png  2022-03-21   0
# 39388  26462  9438FD60-2EED-4FC1-BDE0-3AE05A3317BF  2022-03-21   1
# 39389  26462                        fezuexxmnv.png  2022-03-21   0
# 39390  26462                        fvygcngevl.png  2022-03-21   1
# 39391  26462  CF0A47B9-752D-4FC9-A96F-DDC08AAA2247  2022-03-21   0
# 39392  10982  D713CB5A-AE59-4FA7-9387-39C0B766120A  2022-03-21   3
# 39393  26462                        lyqpzibhsh.png  2022-03-21   0
# 39394  26462                        jdmhexxudc.png  2022-03-21   1
# 39395  26462                        zjcmumrvpp.png  2022-03-22   0
# 39396  26462                        iwwwnyrmtz.png  2022-03-22   4
# 39397  26462                        uvjpltipuw.png  2022-03-22   0
# 39398  26462                        jvbisyqqsu.png  2022-03-21   0
# 39399  26462                        vzenektyaa.png  2022-03-22   0
# 39401  26462                        edquaqyuia.png  2022-03-21   0
# 39402  26462  9B2969BF-F999-43AD-A082-AFFF7615AEC7  2022-03-21   0
# 39403  26462                        zkddsdiwzw.png  2022-03-21   0
# 39404  26462                        jajxlriszt.png  2022-03-22   0
# 39405  26462                        vqkgeemfhy.png  2022-03-22   0
# 39406  26462                        vcubzchjxv.png  2022-03-21   0
# 39407  26462  3340619E-D3F4-4090-B3D0-B6CDF1D9F370  2022-03-21   2
# 39408  26462  AD576EF3-4128-4DCD-93CB-63494C69F326  2022-03-22   0
# 39409  26462                        qukpkgoxfp.png  2022-03-21   0
# 39410  26462  10CBBBC5-3BAC-4927-93B1-24918834B166  2022-03-22   1
# 39414  26462                        dghzdcrtay.png  2022-03-21   0
# 39415  26462                        rryhjijyje.png  2022-03-21   4
# 39416  26462                        ieotqfnqcq.png  2022-03-22   1
# 39417  26462                        cywpeqziic.png  2022-03-21   2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22   2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21   0
# 39420  26462                        vdxxgljykj.png  2022-03-21   1
#
#               phone   site      time                             urine  \
# 39370    iPhone13,4  11069  10-08-34                   ปกติ (เหลืองใส)
# 39371  OPPO CPH1819  11069  10-06-17                              ขุ่น
# 39372  OPPO CPH1819  11069  09-33-02                   ใส่เป็นน้ำเปล่า
# 39373    Vivo V2050  11069  09-31-42                   ปกติ (เหลืองใส)
# 39374    Vivo V2050  11069  09-49-16                   ปกติ (เหลืองใส)
# 39375    Vivo V2050  11069  09-12-19                   ใส่เป็นน้ำเปล่า
# 39376    Vivo V2050  11069  09-32-32                              ขุ่น
# 39377  OPPO CPH1819  11069  09-13-07                              ขุ่น
# 39378    Vivo V2050  11069  09-48-29                   ปกติ (เหลืองใส)
# 39379  OPPO CPH1819  11069  10-08-24                   ปกติ (เหลืองใส)
# 39380    Vivo V2050  11069  11-40-37                   ปกติ (เหลืองใส)
# 39381  OPPO CPH1819  11069  10-59-51                   ปกติ (เหลืองใส)
# 39382  OPPO CPH1819  11069  10-57-27                   ปกติ (เหลืองใส)
# 39383    Vivo V2050  11069  10-56-14                   ปกติ (เหลืองใส)
# 39384     Vivo 1920  11069  13-57-55                   ปกติ (เหลืองใส)
# 39385    iPhone13,4  11069  14-04-13                   ปกติ (เหลืองใส)
# 39386     Vivo 1920  11069  10-08-48                   ปกติ (เหลืองใส)
# 39387     Vivo 1920  11069  10-27-48                   ใส่เป็นน้ำเปล่า
# 39388    iPhone13,4  11069  09-49-51                   ปกติ (เหลืองใส)
# 39389    Vivo V2050  11069  09-48-21                   ปกติ (เหลืองใส)
# 39390     Vivo 1920  11069  10-29-01                   ปกติ (เหลืองใส)
# 39391    iPhone13,4  11069  09-47-58                   ปกติ (เหลืองใส)
# 39392    iPhone13,4  11069  10-30-00                   ปกติ (เหลืองใส)
# 39393     Vivo 1920  11069  11-52-33                   ปกติ (เหลืองใส)
# 39394     Vivo 1920  11069  10-54-05  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
# 39395    Vivo V2050  11069  09-11-13  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
# 39396  OPPO CPH1819  11069  09-32-10                   ปกติ (เหลืองใส)
# 39397     Vivo 1920  11069  13-42-14                   ปกติ (เหลืองใส)
# 39398    Vivo V2050  11069  10-53-58                   ปกติ (เหลืองใส)
# 39399     Vivo 1920  11069  13-41-49                   ปกติ (เหลืองใส)
# 39401     Vivo 1920  11069  10-55-13                   ปกติ (เหลืองใส)
# 39402    iPhone13,4  11069  10-56-13                   ปกติ (เหลืองใส)
# 39403     Vivo 1920  11069  14-17-08                   ปกติ (เหลืองใส)
# 39404     Vivo 1920  11069  14-01-37                   ปกติ (เหลืองใส)
# 39405     Vivo 1920  11069  14-02-37                           มีตะกอน
# 39406     Vivo 1920  11069  14-18-41                   ปกติ (เหลืองใส)
# 39407    iPhone13,4  11069  13-58-41                           มีตะกอน
# 39408    iPhone13,4  11069  13-39-56                   ปกติ (เหลืองใส)
# 39409     Vivo 1920  11069  11-54-17                   ปกติ (เหลืองใส)
# 39410    iPhone13,4  11069  14-01-18                   ปกติ (เหลืองใส)
# 39414     Vivo 1920  11069  11-51-32                           มีตะกอน
# 39415    Vivo V2050  11069  11-52-34                    มีเม็ดเลือดแดง
# 39416     Vivo 1920  11069  14-03-12                   ปกติ (เหลืองใส)
# 39417     Vivo 1920  11069  13-59-04                   ปกติ (เหลืองใส)
# 39418    iPhone13,4  11069  13-41-47                   ปกติ (เหลืองใส)
# 39419    iPhone13,4  11069  14-17-46                   ปกติ (เหลืองใส)
# 39420    Vivo V2050  11069  10-54-49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
#
#        PartitionKey   sex  age
# 39370         10961  หญิง   69
# 39371         10962  หญิง   54
# 39372         10963  หญิง   26
# 39373         10964   ชาย   50
# 39374         10965  หญิง   27
# 39375         10966  หญิง   23
# 39376         10967  หญิง   55
# 39377         10968   ชาย   27
# 39378         10969   ชาย   27
# 39379         10970   ชาย   59
# 39380         10971   ชาย   33
# 39381         10972  หญิง   49
# 39382         10972  หญิง   49
# 39383         10973   ชาย   46
# 39384         10974  หญิง   50
# 39385         10975  หญิง   48
# 39386         10976  หญิง   46
# 39387         10977  หญิง   15
# 39388         10978   ชาย   24
# 39389         10979  หญิง   65
# 39390         10980   ชาย   27
# 39391         10981   ชาย   74
# 39392         10982  หญิง   38
# 39393         10983  หญิง   63
# 39394         10984  หญิง   45
# 39395         10985   ชาย   57
# 39396         10986   ชาย   28
# 39397         10987   ชาย   28
# 39398         10988   ชาย   33
# 39399         10989  หญิง   54
# 39401         10990   ชาย   25
# 39402         10991   ชาย   56
# 39403         10992  หญิง   58
# 39404         10993   ชาย   54
# 39405         10993   ชาย   54
# 39406         10995   ชาย   34
# 39407         10996  หญิง   61
# 39408         10997  หญิง   83
# 39409         10998  หญิง   69
# 39410         10999  หญิง   62
# 39414         11000   ชาย   36
# 39415         11002  หญิง   23
# 39416         11003  หญิง   33
# 39417         11005   ชาย   28
# 39418         11006  หญิง   72
# 39419         11007  หญิง   48
# 39420         11008   ชาย   36

# %%
data_ho = pd.read_excel(os.path.join(path,'hospital_list.xlsx'))
data_ho
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %%
data_ho = data_ho[['hcode','name','zone_name','province','amphur','tambon','name5','short_english']]      # เลือกเฉพาะคอลัมน์ที่ต้องการ
print(data_ho.shape)
data_ho.head()
# Out:
# (17103, 8)
#    hcode                                     name             zone_name  \
# 0  00001      สำนักงานสาธารณสุขจังหวัดสมุทรปราการ    สาขาพื้นที่(ระยอง)
# 1  00002          สำนักงานสาธารณสุขจังหวัดนนทบุรี  สาขาพื้นที่(สระบุรี)
# 2  00003         สำนักงานสาธารณสุขจังหวัดปทุมธานี  สาขาพื้นที่(สระบุรี)
# 3  00004  สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา  สาขาพื้นที่(สระบุรี)
# 4  00005          สำนักงานสาธารณสุขจังหวัดอ่างทอง  สาขาพื้นที่(สระบุรี)
#
#           province            amphur     tambon                     name5  \
# 0      สมุทรปราการ  เมืองสมุทรปราการ     ปากน้ำ  สำนักงานสาธารณสุขจังหวัด
# 1          นนทบุรี      เมืองนนทบุรี   บางกระสอ  สำนักงานสาธารณสุขจังหวัด
# 2         ปทุมธานี     เมืองปทุมธานี    บางปรอก  สำนักงานสาธารณสุขจังหวัด
# 3  พระนครศรีอยุธยา   พระนครศรีอยุธยา  หอรัตนไชย  สำนักงานสาธารณสุขจังหวัด
# 4          อ่างทอง      เมืองอ่างทอง    บ้านอิฐ  สำนักงานสาธารณสุขจังหวัด
#
#   short_english
# 0           SPK
# 1           NBI
# 2           PTE
# 3           AYA
# 4           ATG

# %%
data_ho.isnull().sum()
# Out:
# hcode              0
# name               1
# zone_name          4
# province           0
# amphur             2
# tambon           209
# name5              3
# short_english      6
# dtype: int64

# %%
data_ho['name'] = data_ho['name'].fillna('ไม่ระบุ') 
data_ho['zone_name'] = data_ho['zone_name'].fillna('ไม่ระบุ') 
data_ho['amphur'] = data_ho['amphur'].fillna('ไม่ระบุ') 
data_ho['tambon'] = data_ho['tambon'].fillna('ไม่ระบุ') 
data_ho['name5'] = data_ho['name5'].fillna('ไม่ระบุ') 
data_ho['short_english'] = data_ho['short_english'].fillna('ไม่ระบุ');
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_ho.isnull().sum()
# Out:
# hcode            0
# name             0
# zone_name        0
# province         0
# amphur           0
# tambon           0
# name5            0
# short_english    0
# dtype: int64

# %%
data_use = data_01.merge(data_ho,how='left',left_on='PartitionKey',right_on='hcode')     # เชื่อมตาราง
data_use.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-d993b6b0be74> in <module>()
# ----> 1 data_use = data_01.merge(data_ho,how='left',left_on='PartitionKey',right_on='hcode')     # เชื่อมตาราง
#       2 data_use.head(10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9201             copy=copy,
#    9202             indicator=indicator,
# -> 9203             validate=validate,
#    9204         )
#    9205
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     701         # validate the merge keys dtypes. We may need to coerce
#     702         # to avoid incompatible dtypes
# --> 703         self._maybe_coerce_merge_keys()
#     704
#     705         # If argument passed to validate,
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1254                     inferred_right in string_types and inferred_left not in string_types
#    1255                 ):
# -> 1256                     raise ValueError(msg)
#    1257
#    1258             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat
